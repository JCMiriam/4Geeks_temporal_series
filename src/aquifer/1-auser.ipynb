# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys
import importlib
sys.path.append('../')

import utils
importlib.reload(utils)
# Out:
# <module 'utils' from 'c:\\Users\\USUARIO\\Desktop\\Projects\\4Geeks_temporal_series\\src\\aquifer\\..\\utils.py'>

# %%
df = pd.read_csv('../../data/raw/Aquifer_Auser.csv')
df = utils.turn_column_into_date(df, 'Date')
df.head()
# Out:
#             Rainfall_Gallicano  Rainfall_Pontetetto  Rainfall_Monte_Serra  \
# Date
# 1998-03-05                 NaN                  NaN                   NaN
# 1998-03-06                 NaN                  NaN                   NaN
# 1998-03-07                 NaN                  NaN                   NaN
# 1998-03-08                 NaN                  NaN                   NaN
# 1998-03-09                 NaN                  NaN                   NaN
#
#             Rainfall_Orentano  Rainfall_Borgo_a_Mozzano  Rainfall_Piaggione  \
# Date
# 1998-03-05                NaN                       NaN                 NaN
# 1998-03-06                NaN                       NaN                 NaN
# 1998-03-07                NaN                       NaN                 NaN
# 1998-03-08                NaN                       NaN                 NaN
# 1998-03-09                NaN                       NaN                 NaN
#
#             Rainfall_Calavorno  Rainfall_Croce_Arcana  \
# Date
# 1998-03-05                 NaN                    NaN
# 1998-03-06                 NaN                    NaN
# 1998-03-07                 NaN                    NaN
# 1998-03-08                 NaN                    NaN
# 1998-03-09                 NaN                    NaN
#
#             Rainfall_Tereglio_Coreglia_Antelminelli  \
# Date
# 1998-03-05                                      NaN
# 1998-03-06                                      NaN
# 1998-03-07                                      NaN
# 1998-03-08                                      NaN
# 1998-03-09                                      NaN
#
#             Rainfall_Fabbriche_di_Vallico  ...  Temperature_Monte_Serra  \
# Date                                       ...
# 1998-03-05                            NaN  ...                      0.0
# 1998-03-06                            NaN  ...                      0.0
# 1998-03-07                            NaN  ...                      9.2
# 1998-03-08                            NaN  ...                     11.4
# 1998-03-09                            NaN  ...                     11.4
#
#             Temperature_Ponte_a_Moriano  Temperature_Lucca_Orto_Botanico  \
# Date
# 1998-03-05                          0.0                             0.00
# 1998-03-06                          0.0                            10.05
# 1998-03-07                          0.0                            10.00
# 1998-03-08                          0.0                            13.85
# 1998-03-09                          0.0                            12.85
#
#             Volume_POL  Volume_CC1  Volume_CC2  Volume_CSA  Volume_CSAL  \
# Date
# 1998-03-05         NaN         NaN         NaN         NaN          NaN
# 1998-03-06         NaN         NaN         NaN         NaN          NaN
# 1998-03-07         NaN         NaN         NaN         NaN          NaN
# 1998-03-08         NaN         NaN         NaN         NaN          NaN
# 1998-03-09         NaN         NaN         NaN         NaN          NaN
#
#             Hydrometry_Monte_S_Quirico  Hydrometry_Piaggione
# Date
# 1998-03-05                         NaN                   NaN
# 1998-03-06                         NaN                   NaN
# 1998-03-07                         NaN                   NaN
# 1998-03-08                         NaN                   NaN
# 1998-03-09                         NaN                   NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# # Valores faltantes

# %%
utils.get_null_percentage_per_column(df)
# Out:
# Depth_to_Groundwater_DIEC                  59.896983
# Depth_to_Groundwater_PAG                   53.311258
# Depth_to_Groundwater_CoS                   47.081187
# Depth_to_Groundwater_SAL                   44.260486
# Depth_to_Groundwater_LT2                   41.108658
# Rainfall_Piaggione                         39.538877
# Rainfall_Monte_Serra                       35.136130
# Rainfall_Fabbriche_di_Vallico              35.062546
# Rainfall_Pontetetto                        35.062546
# Rainfall_Gallicano                         35.062546
# Rainfall_Tereglio_Coreglia_Antelminelli    35.062546
# Rainfall_Croce_Arcana                      35.062546
# Rainfall_Calavorno                         35.062546
# Rainfall_Borgo_a_Mozzano                   35.062546
# Rainfall_Orentano                          35.062546
# Volume_POL                                 30.586215
# Volume_CC1                                 30.586215
# Volume_CC2                                 30.586215
# Volume_CSA                                 30.586215
# Volume_CSAL                                30.586215
# Hydrometry_Piaggione                       24.957076
# Hydrometry_Monte_S_Quirico                 11.196959
# Temperature_Orentano                        0.000000
# Temperature_Monte_Serra                     0.000000
# Temperature_Ponte_a_Moriano                 0.000000
# Temperature_Lucca_Orto_Botanico             0.000000
# dtype: float64

# %%
df = utils.remove_columns_with_nulls_percent(df, threshold=50)
df = utils.interpolate_df(df)
# Out:
# Columnas eliminadas por alto porcentaje de valores nulos (50%): ['Depth_to_Groundwater_PAG', 'Depth_to_Groundwater_DIEC']
# Valores nulos después de la interpolación:
# Series([], dtype: int64)
# c:\Users\USUARIO\Desktop\Projects\4Geeks_temporal_series\src\aquifer\..\utils.py:26: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)  # Relleno hacia adelante
# c:\Users\USUARIO\Desktop\Projects\4Geeks_temporal_series\src\aquifer\..\utils.py:27: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)  # Relleno hacia atrás

# %%
utils.get_null_percentage_per_column(df)
# Out:
# Rainfall_Gallicano                         0.0
# Rainfall_Pontetetto                        0.0
# Hydrometry_Monte_S_Quirico                 0.0
# Volume_CSAL                                0.0
# Volume_CSA                                 0.0
# Volume_CC2                                 0.0
# Volume_CC1                                 0.0
# Volume_POL                                 0.0
# Temperature_Lucca_Orto_Botanico            0.0
# Temperature_Ponte_a_Moriano                0.0
# Temperature_Monte_Serra                    0.0
# Temperature_Orentano                       0.0
# Depth_to_Groundwater_CoS                   0.0
# Depth_to_Groundwater_SAL                   0.0
# Depth_to_Groundwater_LT2                   0.0
# Rainfall_Fabbriche_di_Vallico              0.0
# Rainfall_Tereglio_Coreglia_Antelminelli    0.0
# Rainfall_Croce_Arcana                      0.0
# Rainfall_Calavorno                         0.0
# Rainfall_Piaggione                         0.0
# Rainfall_Borgo_a_Mozzano                   0.0
# Rainfall_Orentano                          0.0
# Rainfall_Monte_Serra                       0.0
# Hydrometry_Piaggione                       0.0
# dtype: float64

# %% [markdown]
# # Análisis de tendencias

# %%
utils.plot_trend(df, period=365)

# %% [markdown]
# # Análisis de estacionalidad

# %%
utils.plot_seasonality(df, period=365)

# %% [markdown]
# # Prueba de estacionariedad

# %%
utils.test_stationarity(df)
# Out:
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_Gallicano':
# Test Statistic                   -2.707274
# p-value                           0.072788
# #Lags Used                       37.000000
# Number of Observations Used    8116.000000
# Critical Value (1%)              -3.431156
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566960
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_Pontetetto':
# Test Statistic                   -2.624363
# p-value                           0.088066
# #Lags Used                       35.000000
# Number of Observations Used    8118.000000
# Critical Value (1%)              -3.431156
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566960
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_Monte_Serra':
# Test Statistic                   -3.344290
# p-value                           0.013011
# #Lags Used                       35.000000
# Number of Observations Used    8118.000000
# Critical Value (1%)              -3.431156
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566960
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_Orentano':
# Test Statistic                   -1.677986
# p-value                           0.442489
# #Lags Used                       34.000000
# Number of Observations Used    8119.000000
# Critical Value (1%)              -3.431156
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566960
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_Borgo_a_Mozzano':
# Test Statistic                   -3.014873
# p-value                           0.033529
# #Lags Used                       36.000000
# Number of Observations Used    8117.000000
# Critical Value (1%)              -3.431156
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566960
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_Piaggione':
# Test Statistic                   -2.675306
# p-value                           0.078410
# #Lags Used                       33.000000
# Number of Observations Used    8120.000000
# Critical Value (1%)              -3.431156
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566960
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_Calavorno':
# Test Statistic                   -2.778619
# p-value                           0.061393
# #Lags Used                       36.000000
# Number of Observations Used    8117.000000
# Critical Value (1%)              -3.431156
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566960
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_Croce_Arcana':
# Test Statistic                -1.164591e+01
# p-value                        2.092582e-21
# #Lags Used                     2.800000e+01
# Number of Observations Used    8.125000e+03
# Critical Value (1%)           -3.431155e+00
# Critical Value (5%)           -2.861896e+00
# Critical Value (10%)          -2.566959e+00
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_Tereglio_Coreglia_Antelminelli':
# Test Statistic                -7.383302e+00
# p-value                        8.362275e-11
# #Lags Used                     3.500000e+01
# Number of Observations Used    8.118000e+03
# Critical Value (1%)           -3.431156e+00
# Critical Value (5%)           -2.861896e+00
# Critical Value (10%)          -2.566960e+00
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_Fabbriche_di_Vallico':
# Test Statistic                   -2.946319
# p-value                           0.040221
# #Lags Used                       36.000000
# Number of Observations Used    8117.000000
# Critical Value (1%)              -3.431156
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566960
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Depth_to_Groundwater_LT2':
# Test Statistic                   -0.472712
# p-value                           0.897233
# #Lags Used                       36.000000
# Number of Observations Used    8117.000000
# Critical Value (1%)              -3.431156
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566960
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Depth_to_Groundwater_SAL':
# Test Statistic                   -3.331669
# p-value                           0.013521
# #Lags Used                       37.000000
# Number of Observations Used    8116.000000
# Critical Value (1%)              -3.431156
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566960
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Depth_to_Groundwater_CoS':
# Test Statistic                -7.359097e+00
# p-value                        9.605294e-11
# #Lags Used                     3.600000e+01
# Number of Observations Used    8.117000e+03
# Critical Value (1%)           -3.431156e+00
# Critical Value (5%)           -2.861896e+00
# Critical Value (10%)          -2.566960e+00
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Temperature_Orentano':
# Test Statistic                   -4.403276
# p-value                           0.000293
# #Lags Used                       29.000000
# Number of Observations Used    8124.000000
# Critical Value (1%)              -3.431155
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566959
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Temperature_Monte_Serra':
# Test Statistic                -6.091401e+00
# p-value                        1.034388e-07
# #Lags Used                     1.700000e+01
# Number of Observations Used    8.136000e+03
# Critical Value (1%)           -3.431154e+00
# Critical Value (5%)           -2.861895e+00
# Critical Value (10%)          -2.566959e+00
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Temperature_Ponte_a_Moriano':
# Test Statistic                   -4.645530
# p-value                           0.000106
# #Lags Used                       12.000000
# Number of Observations Used    8141.000000
# Critical Value (1%)              -3.431154
# Critical Value (5%)              -2.861895
# Critical Value (10%)             -2.566959
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Temperature_Lucca_Orto_Botanico':
# Test Statistic                -6.066137e+00
# p-value                        1.180577e-07
# #Lags Used                     3.600000e+01
# Number of Observations Used    8.117000e+03
# Critical Value (1%)           -3.431156e+00
# Critical Value (5%)           -2.861896e+00
# Critical Value (10%)          -2.566960e+00
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Volume_POL':
# Test Statistic                   -2.552928
# p-value                           0.103122
# #Lags Used                       37.000000
# Number of Observations Used    8116.000000
# Critical Value (1%)              -3.431156
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566960
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Volume_CC1':
# Test Statistic                    0.261801
# p-value                           0.975522
# #Lags Used                       37.000000
# Number of Observations Used    8116.000000
# Critical Value (1%)              -3.431156
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566960
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Volume_CC2':
# Test Statistic                   -2.517711
# p-value                           0.111224
# #Lags Used                       36.000000
# Number of Observations Used    8117.000000
# Critical Value (1%)              -3.431156
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566960
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Volume_CSA':
# Test Statistic                   -1.278966
# p-value                           0.638740
# #Lags Used                       37.000000
# Number of Observations Used    8116.000000
# Critical Value (1%)              -3.431156
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566960
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Volume_CSAL':
# Test Statistic                   -2.183749
# p-value                           0.212196
# #Lags Used                       36.000000
# Number of Observations Used    8117.000000
# Critical Value (1%)              -3.431156
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566960
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Hydrometry_Monte_S_Quirico':
# Test Statistic                -7.142072e+00
# p-value                        3.304338e-10
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.116000e+03
# Critical Value (1%)           -3.431156e+00
# Critical Value (5%)           -2.861896e+00
# Critical Value (10%)          -2.566960e+00
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Hydrometry_Piaggione':
# Test Statistic                   -3.346005
# p-value                           0.012943
# #Lags Used                       36.000000
# Number of Observations Used    8117.000000
# Critical Value (1%)              -3.431156
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566960
# dtype: float64
# --------------------------------------------------------------------------------

# %% [markdown]
# # Análisis de variabilidad

# %%
utils.plot_variability(df, period=365)

# %% [markdown]
# # Análisis de autocorrelación

# %%
utils.plot_autocorrelation(df)

# %%
df.to_csv("../../data/processed/aquifer_auser.csv", index=True)
