# %%
# Common imports
import pandas as pd

# %%
# Import from utils
import sys
import importlib
sys.path.append('../')

import utils
importlib.reload(utils)
# Out:
# <module 'utils' from '/workspaces/4Geeks_temporal_series/src/aquifer/../utils.py'>

# %% [markdown]
# # Aquifer Doganella análisis

# %%
aquifer_doganella = pd.read_csv('../../data/raw/Aquifer_Doganella.csv')
aquifer_doganella.head()
# Out:
#          Date  Rainfall_Monteporzio  Rainfall_Velletri  \
# 0  01/01/2004                   0.0                0.0
# 1  02/01/2004                   0.2                0.8
# 2  03/01/2004                   0.0                0.0
# 3  04/01/2004                   0.0                0.0
# 4  05/01/2004                   0.2                0.0
#
#    Depth_to_Groundwater_Pozzo_1  Depth_to_Groundwater_Pozzo_2  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    Depth_to_Groundwater_Pozzo_3  Depth_to_Groundwater_Pozzo_4  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# ...

# %%
utils.get_null_percentage_per_column(aquifer_doganella)
# Out:
# Volume_Pozzo_1                  77.497511
# Volume_Pozzo_5+6                77.431132
# Volume_Pozzo_8                  77.431132
# Volume_Pozzo_9                  77.431132
# Volume_Pozzo_2                  77.431132
# Volume_Pozzo_7                  77.431132
# Volume_Pozzo_4                  77.431132
# Volume_Pozzo_3                  77.431132
# Depth_to_Groundwater_Pozzo_7    61.649519
# Depth_to_Groundwater_Pozzo_9    61.184866
# Depth_to_Groundwater_Pozzo_4    60.604049
# Depth_to_Groundwater_Pozzo_6    59.707932
# Depth_to_Groundwater_Pozzo_5    58.380352
# Depth_to_Groundwater_Pozzo_1    57.899104
# Depth_to_Groundwater_Pozzo_8    57.666777
# Depth_to_Groundwater_Pozzo_2    54.596747
# Depth_to_Groundwater_Pozzo_3    53.966147
# Temperature_Velletri            27.265184
# Temperature_Monteporzio         24.261533
# Rainfall_Velletri               10.819781
# Rainfall_Monteporzio            10.404912
# Date                             0.000000
# dtype: float64

# %%
aquifer_doganella = utils.turn_column_into_date(aquifer_doganella, 'Date')
aquifer_doganella.head(3)
# Out:
#             Rainfall_Monteporzio  Rainfall_Velletri  \
# Date
# 2004-01-01                   0.0                0.0
# 2004-01-02                   0.2                0.8
# 2004-01-03                   0.0                0.0
#
#             Depth_to_Groundwater_Pozzo_1  Depth_to_Groundwater_Pozzo_2  \
# Date
# 2004-01-01                           NaN                           NaN
# 2004-01-02                           NaN                           NaN
# 2004-01-03                           NaN                           NaN
#
#             Depth_to_Groundwater_Pozzo_3  Depth_to_Groundwater_Pozzo_4  \
# Date
# 2004-01-01                           NaN                           NaN
# 2004-01-02                           NaN                           NaN
# 2004-01-03                           NaN                           NaN
#
#             Depth_to_Groundwater_Pozzo_5  Depth_to_Groundwater_Pozzo_6  \
# Date
# 2004-01-01                           NaN                           NaN
# ...

# %%
aquifer_doganella = utils.interpolate_df(aquifer_doganella)
# Out:
# Rainfall_Monteporzio            0
# Rainfall_Velletri               0
# Depth_to_Groundwater_Pozzo_1    0
# Depth_to_Groundwater_Pozzo_2    0
# Depth_to_Groundwater_Pozzo_3    0
# Depth_to_Groundwater_Pozzo_4    0
# Depth_to_Groundwater_Pozzo_5    0
# Depth_to_Groundwater_Pozzo_6    0
# Depth_to_Groundwater_Pozzo_7    0
# Depth_to_Groundwater_Pozzo_8    0
# Depth_to_Groundwater_Pozzo_9    0
# Volume_Pozzo_1                  0
# Volume_Pozzo_2                  0
# Volume_Pozzo_3                  0
# Volume_Pozzo_4                  0
# Volume_Pozzo_5+6                0
# Volume_Pozzo_7                  0
# Volume_Pozzo_8                  0
# Volume_Pozzo_9                  0
# Temperature_Monteporzio         0
# Temperature_Velletri            0
# dtype: int64
# /workspaces/4Geeks_temporal_series/src/aquifer/../utils.py:23: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# ...

# %%
aquifer_doganella = utils.normalize_dataframe(aquifer_doganella)
aquifer_doganella.head(3)
# Out:
#             Rainfall_Monteporzio  Rainfall_Velletri  \
# Date
# 2004-01-01             -0.342227          -0.386949
# 2004-01-02             -0.318366          -0.299723
# 2004-01-03             -0.342227          -0.386949
#
#             Depth_to_Groundwater_Pozzo_1  Depth_to_Groundwater_Pozzo_2  \
# Date
# 2004-01-01                     -0.750504                      0.444572
# 2004-01-02                     -0.750504                      0.444572
# 2004-01-03                     -0.750504                      0.444572
#
#             Depth_to_Groundwater_Pozzo_3  Depth_to_Groundwater_Pozzo_4  \
# Date
# 2004-01-01                      0.649953                      0.465531
# 2004-01-02                      0.649953                      0.465531
# 2004-01-03                      0.649953                      0.465531
#
#             Depth_to_Groundwater_Pozzo_5  Depth_to_Groundwater_Pozzo_6  \
# Date
# 2004-01-01                      0.595222                      0.616644
# ...

# %%
utils.get_null_percentage_per_column(aquifer_doganella)
# Out:
# Rainfall_Monteporzio            0.0
# Rainfall_Velletri               0.0
# Depth_to_Groundwater_Pozzo_1    0.0
# Depth_to_Groundwater_Pozzo_2    0.0
# Depth_to_Groundwater_Pozzo_3    0.0
# Depth_to_Groundwater_Pozzo_4    0.0
# Depth_to_Groundwater_Pozzo_5    0.0
# Depth_to_Groundwater_Pozzo_6    0.0
# Depth_to_Groundwater_Pozzo_7    0.0
# Depth_to_Groundwater_Pozzo_8    0.0
# Depth_to_Groundwater_Pozzo_9    0.0
# Volume_Pozzo_1                  0.0
# Volume_Pozzo_2                  0.0
# Volume_Pozzo_3                  0.0
# Volume_Pozzo_4                  0.0
# Volume_Pozzo_5+6                0.0
# Volume_Pozzo_7                  0.0
# Volume_Pozzo_8                  0.0
# Volume_Pozzo_9                  0.0
# Temperature_Monteporzio         0.0
# Temperature_Velletri            0.0
# dtype: float64

# %%
aquifer_doganella.shape
# Out:
# (6026, 21)

# %% [markdown]
# # Combinar columnas para obtener media del volumen de los acuíferos

# %%
columns = ['Volume_Pozzo_1', 'Volume_Pozzo_2', 'Volume_Pozzo_3', 'Volume_Pozzo_4', 'Volume_Pozzo_5+6', 'Volume_Pozzo_7', 'Volume_Pozzo_8', 'Volume_Pozzo_9']

aquifer_doganella = utils.combine_columns_mean(aquifer_doganella, columns, 'Volume_mean')

# %%
aquifer_doganella.head(3)
# Out:
#             Rainfall_Monteporzio  Rainfall_Velletri  \
# Date
# 2004-01-01             -0.342227          -0.386949
# 2004-01-02             -0.318366          -0.299723
# 2004-01-03             -0.342227          -0.386949
#
#             Depth_to_Groundwater_Pozzo_1  Depth_to_Groundwater_Pozzo_2  \
# Date
# 2004-01-01                     -0.750504                      0.444572
# 2004-01-02                     -0.750504                      0.444572
# 2004-01-03                     -0.750504                      0.444572
#
#             Depth_to_Groundwater_Pozzo_3  Depth_to_Groundwater_Pozzo_4  \
# Date
# 2004-01-01                      0.649953                      0.465531
# 2004-01-02                      0.649953                      0.465531
# 2004-01-03                      0.649953                      0.465531
#
#             Depth_to_Groundwater_Pozzo_5  Depth_to_Groundwater_Pozzo_6  \
# Date
# 2004-01-01                      0.595222                      0.616644
# ...

# %%
aquifer_doganella.to_csv("../../data/processed/aquifer_doganella.csv", index=True)

# %% [markdown]
# # Tendencia y estacionalidad

# %%
utils.plot_trend(aquifer_doganella, 12)

# %%
utils.plot_seasonality(aquifer_doganella, 12)

# %% [markdown]
# # Prueba de Dickey-Fuller

# %%
utils.test_stationarity(aquifer_doganella)
# Out:
# Resultados de la prueba de Dickey-Fuller para la columna 'Rainfall_Monteporzio':
# Test Statistic                -1.055126e+01
# p-value                        8.164912e-19
# #Lags Used                     3.100000e+01
# Number of Observations Used    5.994000e+03
# Critical Value (1%)           -3.431441e+00
# Critical Value (5%)           -2.862022e+00
# Critical Value (10%)          -2.567027e+00
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para la columna 'Rainfall_Velletri':
# Test Statistic                -8.434232e+00
# p-value                        1.835062e-13
# #Lags Used                     2.700000e+01
# Number of Observations Used    5.998000e+03
# Critical Value (1%)           -3.431441e+00
# Critical Value (5%)           -2.862022e+00
# Critical Value (10%)          -2.567027e+00
# dtype: float64
# ...

# %% [markdown]
# # Análisis de variabilidad

# %%
utils.plot_variability(aquifer_doganella, 12)

# %% [markdown]
# # Análisis de la autocorrelación

# %%
utils.plot_autocorrelation(aquifer_doganella)
