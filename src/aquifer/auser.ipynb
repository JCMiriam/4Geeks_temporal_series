# %%
# Common imports
import pandas as pd

# %%
# Import from utils
import sys
import importlib
sys.path.append('../')

import utils
importlib.reload(utils)
# Out:
# <module 'utils' from '/workspaces/4Geeks_temporal_series/src/aquifer/../utils.py'>

# %% [markdown]
# # Aquifer Auser análisis

# %%
aquifer_auser = pd.read_csv('../../data/raw/Aquifer_Auser.csv')
aquifer_auser.head()
# Out:
#          Date  Rainfall_Gallicano  Rainfall_Pontetetto  Rainfall_Monte_Serra  \
# 0  05/03/1998                 NaN                  NaN                   NaN
# 1  06/03/1998                 NaN                  NaN                   NaN
# 2  07/03/1998                 NaN                  NaN                   NaN
# 3  08/03/1998                 NaN                  NaN                   NaN
# 4  09/03/1998                 NaN                  NaN                   NaN
#
#    Rainfall_Orentano  Rainfall_Borgo_a_Mozzano  Rainfall_Piaggione  \
# 0                NaN                       NaN                 NaN
# 1                NaN                       NaN                 NaN
# 2                NaN                       NaN                 NaN
# 3                NaN                       NaN                 NaN
# 4                NaN                       NaN                 NaN
#
#    Rainfall_Calavorno  Rainfall_Croce_Arcana  \
# 0                 NaN                    NaN
# ...

# %%
utils.get_null_percentage_per_column(aquifer_auser)
# Out:
# Depth_to_Groundwater_DIEC                  59.896983
# Depth_to_Groundwater_PAG                   53.311258
# Depth_to_Groundwater_CoS                   47.081187
# Depth_to_Groundwater_SAL                   44.260486
# Depth_to_Groundwater_LT2                   41.108658
# Rainfall_Piaggione                         39.538877
# Rainfall_Monte_Serra                       35.136130
# Rainfall_Calavorno                         35.062546
# Rainfall_Pontetetto                        35.062546
# Rainfall_Orentano                          35.062546
# Rainfall_Gallicano                         35.062546
# Rainfall_Borgo_a_Mozzano                   35.062546
# Rainfall_Fabbriche_di_Vallico              35.062546
# Rainfall_Croce_Arcana                      35.062546
# Rainfall_Tereglio_Coreglia_Antelminelli    35.062546
# Volume_CSAL                                30.586215
# Volume_CC2                                 30.586215
# Volume_CC1                                 30.586215
# ...

# %%
aquifer_auser = utils.turn_column_into_date(aquifer_auser, 'Date')
aquifer_auser.head(3)
# Out:
#             Rainfall_Gallicano  Rainfall_Pontetetto  Rainfall_Monte_Serra  \
# Date
# 1998-03-05                 NaN                  NaN                   NaN
# 1998-03-06                 NaN                  NaN                   NaN
# 1998-03-07                 NaN                  NaN                   NaN
#
#             Rainfall_Orentano  Rainfall_Borgo_a_Mozzano  Rainfall_Piaggione  \
# Date
# 1998-03-05                NaN                       NaN                 NaN
# 1998-03-06                NaN                       NaN                 NaN
# 1998-03-07                NaN                       NaN                 NaN
#
#             Rainfall_Calavorno  Rainfall_Croce_Arcana  \
# Date
# 1998-03-05                 NaN                    NaN
# 1998-03-06                 NaN                    NaN
# 1998-03-07                 NaN                    NaN
#
#             Rainfall_Tereglio_Coreglia_Antelminelli  \
# Date
# 1998-03-05                                      NaN
# ...

# %%
aquifer_auser = utils.interpolate_df(aquifer_auser)
# Out:
# Rainfall_Gallicano                         0
# Rainfall_Pontetetto                        0
# Rainfall_Monte_Serra                       0
# Rainfall_Orentano                          0
# Rainfall_Borgo_a_Mozzano                   0
# Rainfall_Piaggione                         0
# Rainfall_Calavorno                         0
# Rainfall_Croce_Arcana                      0
# Rainfall_Tereglio_Coreglia_Antelminelli    0
# Rainfall_Fabbriche_di_Vallico              0
# Depth_to_Groundwater_LT2                   0
# Depth_to_Groundwater_SAL                   0
# Depth_to_Groundwater_PAG                   0
# Depth_to_Groundwater_CoS                   0
# Depth_to_Groundwater_DIEC                  0
# Temperature_Orentano                       0
# Temperature_Monte_Serra                    0
# Temperature_Ponte_a_Moriano                0
# Temperature_Lucca_Orto_Botanico            0
# Volume_POL                                 0
# Volume_CC1                                 0
# ...

# %%
aquifer_auser = utils.normalize_dataframe(aquifer_auser)
aquifer_auser.head(3)
# Out:
#             Rainfall_Gallicano  Rainfall_Pontetetto  Rainfall_Monte_Serra  \
# Date
# 1998-03-05            1.087562              1.08917              0.941376
# 1998-03-06            1.087562              1.08917              0.941376
# 1998-03-07            1.087562              1.08917              0.941376
#
#             Rainfall_Orentano  Rainfall_Borgo_a_Mozzano  Rainfall_Piaggione  \
# Date
# 1998-03-05           1.276821                  1.027303            1.089196
# 1998-03-06           1.276821                  1.027303            1.089196
# 1998-03-07           1.276821                  1.027303            1.089196
#
#             Rainfall_Calavorno  Rainfall_Croce_Arcana  \
# Date
# 1998-03-05            1.067619              -0.244519
# 1998-03-06            1.067619              -0.244519
# 1998-03-07            1.067619              -0.244519
#
#             Rainfall_Tereglio_Coreglia_Antelminelli  \
# Date
# 1998-03-05                                 0.475799
# ...

# %%
utils.get_null_percentage_per_column(aquifer_auser)
# Out:
# Rainfall_Gallicano                         0.0
# Rainfall_Pontetetto                        0.0
# Rainfall_Monte_Serra                       0.0
# Rainfall_Orentano                          0.0
# Rainfall_Borgo_a_Mozzano                   0.0
# Rainfall_Piaggione                         0.0
# Rainfall_Calavorno                         0.0
# Rainfall_Croce_Arcana                      0.0
# Rainfall_Tereglio_Coreglia_Antelminelli    0.0
# Rainfall_Fabbriche_di_Vallico              0.0
# Depth_to_Groundwater_LT2                   0.0
# Depth_to_Groundwater_SAL                   0.0
# Depth_to_Groundwater_PAG                   0.0
# Depth_to_Groundwater_CoS                   0.0
# Depth_to_Groundwater_DIEC                  0.0
# Temperature_Orentano                       0.0
# Temperature_Monte_Serra                    0.0
# Temperature_Ponte_a_Moriano                0.0
# Temperature_Lucca_Orto_Botanico            0.0
# Volume_POL                                 0.0
# ...

# %%
aquifer_auser.shape
# Out:
# (8154, 26)

# %% [markdown]
# # Combinar columnas para obtener media del volumen de los acuíferos

# %%
columns = ['Volume_POL']

aquifer_auser = utils.combine_columns_mean(aquifer_auser, columns, 'Volume_mean')

# %%
aquifer_auser.head(3)
# Out:
#             Rainfall_Gallicano  Rainfall_Pontetetto  Rainfall_Monte_Serra  \
# Date
# 1998-03-05            1.087562              1.08917              0.941376
# 1998-03-06            1.087562              1.08917              0.941376
# 1998-03-07            1.087562              1.08917              0.941376
#
#             Rainfall_Orentano  Rainfall_Borgo_a_Mozzano  Rainfall_Piaggione  \
# Date
# 1998-03-05           1.276821                  1.027303            1.089196
# 1998-03-06           1.276821                  1.027303            1.089196
# 1998-03-07           1.276821                  1.027303            1.089196
#
#             Rainfall_Calavorno  Rainfall_Croce_Arcana  \
# Date
# 1998-03-05            1.067619              -0.244519
# 1998-03-06            1.067619              -0.244519
# 1998-03-07            1.067619              -0.244519
#
#             Rainfall_Tereglio_Coreglia_Antelminelli  \
# Date
# 1998-03-05                                 0.475799
# ...

# %%
aquifer_auser.to_csv("../../data/processed/aquifer_auser.csv", index=True)

# %% [markdown]
# # Tendencia y estacionalidad

# %%
utils.plot_trend(aquifer_auser, 12)

# %%
utils.plot_seasonality(aquifer_auser, 12)

# %% [markdown]
# # Prueba de Dickey-Fuller

# %%
utils.test_stationarity(aquifer_auser)
# Out:
# Resultados de la prueba de Dickey-Fuller para la columna 'Rainfall_Gallicano':
# Test Statistic                   -2.707274
# p-value                           0.072788
# #Lags Used                       37.000000
# Number of Observations Used    8116.000000
# Critical Value (1%)              -3.431156
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566960
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para la columna 'Rainfall_Pontetetto':
# Test Statistic                   -2.624363
# p-value                           0.088066
# #Lags Used                       35.000000
# Number of Observations Used    8118.000000
# Critical Value (1%)              -3.431156
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566960
# dtype: float64
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Análisis de variabilidad

# %%
utils.plot_variability(aquifer_auser, 12)

# %% [markdown]
# # Análisis de la autocorrelación

# %%
utils.plot_autocorrelation(aquifer_auser)

# %%
aquifer_auser
# Out:
#             Rainfall_Gallicano  Rainfall_Pontetetto  Rainfall_Monte_Serra  \
# Date
# 1998-03-05            1.087562             1.089170              0.941376
# 1998-03-06            1.087562             1.089170              0.941376
# 1998-03-07            1.087562             1.089170              0.941376
# 1998-03-08            1.087562             1.089170              0.941376
# 1998-03-09            1.087562             1.089170              0.941376
# ...                        ...                  ...                   ...
# 2020-06-26           -0.844209            -0.848605             -0.832890
# 2020-06-27           -0.844209            -0.848605             -0.832890
# 2020-06-28           -0.844209            -0.848605             -0.832890
# 2020-06-29           -0.844209            -0.848605             -0.832890
# 2020-06-30           -0.844209            -0.848605             -0.832890
#
# ...
