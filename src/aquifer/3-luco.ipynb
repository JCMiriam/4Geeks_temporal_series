# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys
import importlib
sys.path.append('../')

import utils
importlib.reload(utils)
# Out:
# <module 'utils' from 'c:\\Users\\USUARIO\\Desktop\\Projects\\4Geeks_temporal_series\\src\\aquifer\\..\\utils.py'>

# %%
df = pd.read_csv('../../data/raw/Aquifer_Luco.csv')
df = utils.turn_column_into_date(df, 'Date')
df.head()
# Out:
#             Rainfall_Simignano  Rainfall_Siena_Poggio_al_Vento  \
# Date
# 2000-01-01                 NaN                             NaN
# 2000-01-02                 NaN                             NaN
# 2000-01-03                 NaN                             NaN
# 2000-01-04                 NaN                             NaN
# 2000-01-05                 NaN                             NaN
#
#             Rainfall_Mensano  Rainfall_Montalcinello  \
# Date
# 2000-01-01               NaN                     NaN
# 2000-01-02               NaN                     NaN
# 2000-01-03               NaN                     NaN
# 2000-01-04               NaN                     NaN
# 2000-01-05               NaN                     NaN
#
#             Rainfall_Monticiano_la_Pineta  Rainfall_Sovicille  \
# Date
# 2000-01-01                            NaN                 NaN
# 2000-01-02                            NaN                 NaN
# 2000-01-03                            NaN                 NaN
# 2000-01-04                            NaN                 NaN
# 2000-01-05                            NaN                 NaN
#
#             Rainfall_Ponte_Orgia  Rainfall_Scorgiano  Rainfall_Pentolina  \
# Date
# 2000-01-01                   NaN                 NaN                 NaN
# 2000-01-02                   NaN                 NaN                 NaN
# 2000-01-03                   NaN                 NaN                 NaN
# 2000-01-04                   NaN                 NaN                 NaN
# 2000-01-05                   NaN                 NaN                 NaN
#
#             Rainfall_Monteroni_Arbia_Biena  ...  Depth_to_Groundwater_Pozzo_1  \
# Date                                        ...
# 2000-01-01                             NaN  ...                           NaN
# 2000-01-02                             NaN  ...                           NaN
# 2000-01-03                             NaN  ...                           NaN
# 2000-01-04                             NaN  ...                           NaN
# 2000-01-05                             NaN  ...                           NaN
#
#             Depth_to_Groundwater_Pozzo_3  Depth_to_Groundwater_Pozzo_4  \
# Date
# 2000-01-01                           NaN                           NaN
# 2000-01-02                           NaN                           NaN
# 2000-01-03                           NaN                           NaN
# 2000-01-04                           NaN                           NaN
# 2000-01-05                           NaN                           NaN
#
#             Temperature_Siena_Poggio_al_Vento  Temperature_Mensano  \
# Date
# 2000-01-01                                0.0                  0.0
# 2000-01-02                                0.0                  0.0
# 2000-01-03                                0.0                  0.0
# 2000-01-04                                0.0                  0.0
# 2000-01-05                                0.0                  0.0
#
#             Temperature_Pentolina  Temperature_Monteroni_Arbia_Biena  \
# Date
# 2000-01-01                   5.50                               0.80
# 2000-01-02                   6.20                               3.25
# 2000-01-03                   7.25                               0.95
# 2000-01-04                   7.00                               4.20
# 2000-01-05                   7.90                               6.55
#
#             Volume_Pozzo_1  Volume_Pozzo_3  Volume_Pozzo_4
# Date
# 2000-01-01             NaN             NaN             NaN
# 2000-01-02             NaN             NaN             NaN
# 2000-01-03             NaN             NaN             NaN
# 2000-01-04             NaN             NaN             NaN
# 2000-01-05             NaN             NaN             NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# # Valores faltantes

# %%
utils.get_null_percentage_per_column(df)
# Out:
# Depth_to_Groundwater_Pozzo_3           87.712034
# Rainfall_Siena_Poggio_al_Vento         87.297983
# Depth_to_Groundwater_Pozzo_4           87.057566
# Depth_to_Groundwater_Pozzo_1           86.483238
# Rainfall_Ponte_Orgia                   83.170829
# Rainfall_Mensano                       77.000134
# Volume_Pozzo_4                         73.180179
# Volume_Pozzo_3                         73.180179
# Volume_Pozzo_1                         73.180179
# Rainfall_Pentolina                     71.737679
# Rainfall_Monticiano_la_Pineta          70.548952
# Rainfall_Scorgiano                     59.449713
# Rainfall_Monteroni_Arbia_Biena         58.541472
# Depth_to_Groundwater_Podere_Casetta    55.309203
# Rainfall_Montalcinello                 12.848938
# Rainfall_Sovicille                     11.085882
# Rainfall_Simignano                      8.882062
# Temperature_Siena_Poggio_al_Vento       0.000000
# Temperature_Mensano                     0.000000
# Temperature_Pentolina                   0.000000
# Temperature_Monteroni_Arbia_Biena       0.000000
# dtype: float64

# %%
df = utils.remove_columns_with_nulls_percent(df, threshold=50)
df = utils.interpolate_df(df)
# Out:
# Columnas eliminadas por alto porcentaje de valores nulos (50%): ['Rainfall_Siena_Poggio_al_Vento', 'Rainfall_Mensano', 'Rainfall_Monticiano_la_Pineta', 'Rainfall_Ponte_Orgia', 'Rainfall_Scorgiano', 'Rainfall_Pentolina', 'Rainfall_Monteroni_Arbia_Biena', 'Depth_to_Groundwater_Podere_Casetta', 'Depth_to_Groundwater_Pozzo_1', 'Depth_to_Groundwater_Pozzo_3', 'Depth_to_Groundwater_Pozzo_4', 'Volume_Pozzo_1', 'Volume_Pozzo_3', 'Volume_Pozzo_4']
# Valores nulos después de la interpolación:
# Series([], dtype: int64)
# c:\Users\USUARIO\Desktop\Projects\4Geeks_temporal_series\src\aquifer\..\utils.py:26: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)  # Relleno hacia adelante
# c:\Users\USUARIO\Desktop\Projects\4Geeks_temporal_series\src\aquifer\..\utils.py:27: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)  # Relleno hacia atrás

# %%
utils.get_null_percentage_per_column(df)
# Out:
# Rainfall_Simignano                   0.0
# Rainfall_Montalcinello               0.0
# Rainfall_Sovicille                   0.0
# Temperature_Siena_Poggio_al_Vento    0.0
# Temperature_Mensano                  0.0
# Temperature_Pentolina                0.0
# Temperature_Monteroni_Arbia_Biena    0.0
# dtype: float64

# %% [markdown]
# # Análisis de tendencias

# %%
utils.plot_trend(df, period=365)

# %% [markdown]
# # Análisis de estacionalidad

# %%
utils.plot_seasonality(df, period=365)

# %% [markdown]
# # Prueba de estacionariedad

# %%
utils.test_stationarity(df)
# Out:
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_Simignano':
# Test Statistic                -1.101680e+01
# p-value                        6.127604e-20
# #Lags Used                     2.800000e+01
# Number of Observations Used    7.458000e+03
# Critical Value (1%)           -3.431227e+00
# Critical Value (5%)           -2.861928e+00
# Critical Value (10%)          -2.566976e+00
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_Montalcinello':
# Test Statistic                -1.252945e+01
# p-value                        2.446952e-23
# #Lags Used                     2.800000e+01
# Number of Observations Used    7.458000e+03
# Critical Value (1%)           -3.431227e+00
# Critical Value (5%)           -2.861928e+00
# Critical Value (10%)          -2.566976e+00
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_Sovicille':
# Test Statistic                -1.012054e+01
# p-value                        9.471004e-18
# #Lags Used                     3.400000e+01
# Number of Observations Used    7.452000e+03
# Critical Value (1%)           -3.431228e+00
# Critical Value (5%)           -2.861928e+00
# Critical Value (10%)          -2.566976e+00
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Temperature_Siena_Poggio_al_Vento':
# Test Statistic                   -0.994136
# p-value                           0.755397
# #Lags Used                       33.000000
# Number of Observations Used    7453.000000
# Critical Value (1%)              -3.431228
# Critical Value (5%)              -2.861928
# Critical Value (10%)             -2.566976
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Temperature_Mensano':
# Test Statistic                   -2.149373
# p-value                           0.225130
# #Lags Used                       30.000000
# Number of Observations Used    7456.000000
# Critical Value (1%)              -3.431227
# Critical Value (5%)              -2.861928
# Critical Value (10%)             -2.566976
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Temperature_Pentolina':
# Test Statistic                   -5.191690
# p-value                           0.000009
# #Lags Used                       16.000000
# Number of Observations Used    7470.000000
# Critical Value (1%)              -3.431226
# Critical Value (5%)              -2.861927
# Critical Value (10%)             -2.566976
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Temperature_Monteroni_Arbia_Biena':
# Test Statistic                   -5.464733
# p-value                           0.000002
# #Lags Used                       17.000000
# Number of Observations Used    7469.000000
# Critical Value (1%)              -3.431226
# Critical Value (5%)              -2.861927
# Critical Value (10%)             -2.566976
# dtype: float64
# --------------------------------------------------------------------------------

# %% [markdown]
# # Análisis de variabilidad

# %%
utils.plot_variability(df, period=365)

# %% [markdown]
# # Análisis de autocorrelación

# %%
utils.plot_autocorrelation(df)

# %%
df.to_csv("../../data/processed/aquifer_luco.csv", index=True)
