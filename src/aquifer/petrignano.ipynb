# %%
# Common imports
import pandas as pd

# %%
# Import from utils
import sys
import importlib
sys.path.append('../')

import utils
importlib.reload(utils)
# Out:
# <module 'utils' from '/workspaces/4Geeks_temporal_series/src/aquifer/../utils.py'>

# %% [markdown]
# # Aquifer Petrignano análisis

# %%
aquifer_petrignano = pd.read_csv('../../data/raw/Aquifer_Petrignano.csv')
aquifer_petrignano.head()
# Out:
#          Date  Rainfall_Bastia_Umbra  Depth_to_Groundwater_P24  \
# 0  14/03/2006                    NaN                    -22.48
# 1  15/03/2006                    NaN                    -22.38
# 2  16/03/2006                    NaN                    -22.25
# 3  17/03/2006                    NaN                    -22.38
# 4  18/03/2006                    NaN                    -22.60
#
#    Depth_to_Groundwater_P25  Temperature_Bastia_Umbra  Temperature_Petrignano  \
# 0                    -22.18                       NaN                     NaN
# 1                    -22.14                       NaN                     NaN
# 2                    -22.04                       NaN                     NaN
# 3                    -22.04                       NaN                     NaN
# 4                    -22.04                       NaN                     NaN
#
#    Volume_C10_Petrignano  Hydrometry_Fiume_Chiascio_Petrignano
# ...

# %%
utils.get_null_percentage_per_column(aquifer_petrignano)
# Out:
# Rainfall_Bastia_Umbra                   19.605591
# Hydrometry_Fiume_Chiascio_Petrignano    19.605591
# Temperature_Petrignano                  19.605591
# Temperature_Bastia_Umbra                19.605591
# Volume_C10_Petrignano                    3.790925
# Depth_to_Groundwater_P24                 1.053035
# Depth_to_Groundwater_P25                 0.746697
# Date                                     0.000000
# dtype: float64

# %%
aquifer_petrignano = utils.turn_column_into_date(aquifer_petrignano, 'Date')
aquifer_petrignano.head(3)
# Out:
#             Rainfall_Bastia_Umbra  Depth_to_Groundwater_P24  \
# Date
# 2006-03-14                    NaN                    -22.48
# 2006-03-15                    NaN                    -22.38
# 2006-03-16                    NaN                    -22.25
#
#             Depth_to_Groundwater_P25  Temperature_Bastia_Umbra  \
# Date
# 2006-03-14                    -22.18                       NaN
# 2006-03-15                    -22.14                       NaN
# 2006-03-16                    -22.04                       NaN
#
#             Temperature_Petrignano  Volume_C10_Petrignano  \
# Date
# 2006-03-14                     NaN                    NaN
# 2006-03-15                     NaN                    NaN
# 2006-03-16                     NaN                    NaN
#
#             Hydrometry_Fiume_Chiascio_Petrignano
# Date
# 2006-03-14                                   NaN
# 2006-03-15                                   NaN
# 2006-03-16                                   NaN

# %%
aquifer_petrignano = utils.interpolate_df(aquifer_petrignano)
# Out:
# Rainfall_Bastia_Umbra                   0
# Depth_to_Groundwater_P24                0
# Depth_to_Groundwater_P25                0
# Temperature_Bastia_Umbra                0
# Temperature_Petrignano                  0
# Volume_C10_Petrignano                   0
# Hydrometry_Fiume_Chiascio_Petrignano    0
# dtype: int64
# /workspaces/4Geeks_temporal_series/src/aquifer/../utils.py:23: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# /workspaces/4Geeks_temporal_series/src/aquifer/../utils.py:24: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)

# %%
aquifer_petrignano = utils.normalize_dataframe(aquifer_petrignano)
aquifer_petrignano.head(3)
# Out:
#             Rainfall_Bastia_Umbra  Depth_to_Groundwater_P24  \
# Date
# 2006-03-14              -0.265214                  1.146638
# 2006-03-15              -0.265214                  1.176813
# 2006-03-16              -0.265214                  1.216040
#
#             Depth_to_Groundwater_P25  Temperature_Bastia_Umbra  \
# Date
# 2006-03-14                  1.091254                 -0.987356
# 2006-03-15                  1.103668                 -0.987356
# 2006-03-16                  1.134704                 -0.987356
#
#             Temperature_Petrignano  Volume_C10_Petrignano  \
# Date
# 2006-03-14               -0.917504              -0.049328
# 2006-03-15               -0.917504              -0.049328
# 2006-03-16               -0.917504              -0.049328
#
#             Hydrometry_Fiume_Chiascio_Petrignano
# Date
# 2006-03-14                              0.041827
# 2006-03-15                              0.041827
# 2006-03-16                              0.041827

# %%
utils.get_null_percentage_per_column(aquifer_petrignano)
# Out:
# Rainfall_Bastia_Umbra                   0.0
# Depth_to_Groundwater_P24                0.0
# Depth_to_Groundwater_P25                0.0
# Temperature_Bastia_Umbra                0.0
# Temperature_Petrignano                  0.0
# Volume_C10_Petrignano                   0.0
# Hydrometry_Fiume_Chiascio_Petrignano    0.0
# dtype: float64

# %%
aquifer_petrignano.shape
# Out:
# (5223, 7)

# %% [markdown]
# # Combinar columnas para obtener media del volumen de los acuíferos

# %%
columns = ['Volume_C10_Petrignano']

aquifer_petrignano = utils.combine_columns_mean(aquifer_petrignano, columns, 'Volume_mean')

# %%
aquifer_petrignano.head(3)
# Out:
#             Rainfall_Bastia_Umbra  Depth_to_Groundwater_P24  \
# Date
# 2006-03-14              -0.265214                  1.146638
# 2006-03-15              -0.265214                  1.176813
# 2006-03-16              -0.265214                  1.216040
#
#             Depth_to_Groundwater_P25  Temperature_Bastia_Umbra  \
# Date
# 2006-03-14                  1.091254                 -0.987356
# 2006-03-15                  1.103668                 -0.987356
# 2006-03-16                  1.134704                 -0.987356
#
#             Temperature_Petrignano  Volume_C10_Petrignano  \
# Date
# 2006-03-14               -0.917504              -0.049328
# 2006-03-15               -0.917504              -0.049328
# 2006-03-16               -0.917504              -0.049328
#
#             Hydrometry_Fiume_Chiascio_Petrignano  Volume_mean
# Date
# 2006-03-14                              0.041827    -0.049328
# 2006-03-15                              0.041827    -0.049328
# ...

# %%
aquifer_petrignano.to_csv("../../data/processed/aquifer_petrignano.csv", index=True)

# %% [markdown]
# # Tendencia y estacionalidad

# %%
utils.plot_trend(aquifer_petrignano, 12)

# %%
utils.plot_seasonality(aquifer_petrignano, 12)

# %% [markdown]
# # Prueba de Dickey-Fuller

# %%
utils.test_stationarity(aquifer_petrignano)
# Out:
# Resultados de la prueba de Dickey-Fuller para la columna 'Rainfall_Bastia_Umbra':
# Test Statistic                -1.420540e+01
# p-value                        1.758457e-26
# #Lags Used                     1.500000e+01
# Number of Observations Used    5.207000e+03
# Critical Value (1%)           -3.431606e+00
# Critical Value (5%)           -2.862095e+00
# Critical Value (10%)          -2.567066e+00
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para la columna 'Depth_to_Groundwater_P24':
# Test Statistic                   -2.740968
# p-value                           0.067213
# #Lags Used                       30.000000
# Number of Observations Used    5192.000000
# Critical Value (1%)              -3.431610
# Critical Value (5%)              -2.862097
# Critical Value (10%)             -2.567066
# dtype: float64
# ...

# %% [markdown]
# # Análisis de variabilidad

# %%
utils.plot_variability(aquifer_petrignano, 12)

# %% [markdown]
# # Análisis de la autocorrelación

# %%
utils.plot_autocorrelation(aquifer_petrignano)
