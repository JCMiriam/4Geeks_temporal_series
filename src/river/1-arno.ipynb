# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys
import importlib
sys.path.append('../')

import utils
importlib.reload(utils)
# Out:
# <module 'utils' from 'c:\\Users\\USUARIO\\Desktop\\Projects\\4Geeks_temporal_series\\src\\river\\..\\utils.py'>

# %%
df = pd.read_csv('../../data/raw/River_Arno.csv')
df = utils.turn_column_into_date(df, 'Date')
df.head()
# Out:
#             Rainfall_Le_Croci  Rainfall_Cavallina  Rainfall_S_Agata  \
# Date
# 1998-01-01                NaN                 NaN               NaN
# 1998-01-02                NaN                 NaN               NaN
# 1998-01-03                NaN                 NaN               NaN
# 1998-01-04                NaN                 NaN               NaN
# 1998-01-05                NaN                 NaN               NaN
#
#             Rainfall_Mangona  Rainfall_S_Piero  Rainfall_Vernio  \
# Date
# 1998-01-01               NaN               NaN              NaN
# 1998-01-02               NaN               NaN              NaN
# 1998-01-03               NaN               NaN              NaN
# 1998-01-04               NaN               NaN              NaN
# 1998-01-05               NaN               NaN              NaN
#
#             Rainfall_Stia  Rainfall_Consuma  Rainfall_Incisa  \
# Date
# 1998-01-01            NaN               NaN              NaN
# 1998-01-02            NaN               NaN              NaN
# 1998-01-03            NaN               NaN              NaN
# 1998-01-04            NaN               NaN              NaN
# 1998-01-05            NaN               NaN              NaN
#
#             Rainfall_Montevarchi  Rainfall_S_Savino  Rainfall_Laterina  \
# Date
# 1998-01-01                   NaN                NaN                NaN
# 1998-01-02                   NaN                NaN                NaN
# 1998-01-03                   NaN                NaN                NaN
# 1998-01-04                   NaN                NaN                NaN
# 1998-01-05                   NaN                NaN                NaN
#
#             Rainfall_Bibbiena  Rainfall_Camaldoli  Temperature_Firenze  \
# Date
# 1998-01-01                NaN                 NaN                  NaN
# 1998-01-02                NaN                 NaN                  NaN
# 1998-01-03                NaN                 NaN                  NaN
# 1998-01-04                NaN                 NaN                  NaN
# 1998-01-05                NaN                 NaN                  NaN
#
#             Hydrometry_Nave_di_Rosano
# Date
# 1998-01-01                       1.82
# 1998-01-02                       1.94
# 1998-01-03                       2.11
# 1998-01-04                       1.84
# 1998-01-05                       1.88

# %% [markdown]
# # Valores faltantes

# %%
utils.get_null_percentage_per_column(df)
# Out:
# Rainfall_Stia                84.386029
# Rainfall_Consuma             84.386029
# Rainfall_S_Savino            84.386029
# Rainfall_Laterina            84.386029
# Rainfall_Camaldoli           84.386029
# Rainfall_Montevarchi         79.956188
# Rainfall_Bibbiena            71.059998
# Rainfall_Vernio              47.876354
# Rainfall_Incisa              44.407935
# Rainfall_Le_Croci            26.664233
# Rainfall_Cavallina           26.664233
# Rainfall_S_Agata             26.664233
# Rainfall_Mangona             26.664233
# Rainfall_S_Piero             26.664233
# Temperature_Firenze          24.644031
# Hydrometry_Nave_di_Rosano     0.584155
# dtype: float64

# %%
df = utils.remove_columns_with_nulls_percent(df, threshold=50)
df = utils.interpolate_df(df)
# Out:
# Columnas eliminadas por alto porcentaje de valores nulos (50%): ['Rainfall_Stia', 'Rainfall_Consuma', 'Rainfall_Montevarchi', 'Rainfall_S_Savino', 'Rainfall_Laterina', 'Rainfall_Bibbiena', 'Rainfall_Camaldoli']
# Valores nulos después de la interpolación:
# Series([], dtype: int64)
# c:\Users\USUARIO\Desktop\Projects\4Geeks_temporal_series\src\river\..\utils.py:26: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)  # Relleno hacia adelante
# c:\Users\USUARIO\Desktop\Projects\4Geeks_temporal_series\src\river\..\utils.py:27: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)  # Relleno hacia atrás

# %%
utils.get_null_percentage_per_column(df)
# Out:
# Rainfall_Le_Croci            0.0
# Rainfall_Cavallina           0.0
# Rainfall_S_Agata             0.0
# Rainfall_Mangona             0.0
# Rainfall_S_Piero             0.0
# Rainfall_Vernio              0.0
# Rainfall_Incisa              0.0
# Temperature_Firenze          0.0
# Hydrometry_Nave_di_Rosano    0.0
# dtype: float64

# %% [markdown]
# # Análisis de tendencias

# %%
utils.plot_trend(df, period=365)

# %% [markdown]
# # Análisis de estacionalidad

# %%
utils.plot_seasonality(df, period=365)

# %% [markdown]
# # Prueba de estacionariedad

# %%
utils.test_stationarity(df)
# Out:
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_Le_Croci':
# Test Statistic                -1.141247e+01
# p-value                        7.194185e-21
# #Lags Used                     2.700000e+01
# Number of Observations Used    8.189000e+03
# Critical Value (1%)           -3.431149e+00
# Critical Value (5%)           -2.861893e+00
# Critical Value (10%)          -2.566958e+00
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_Cavallina':
# Test Statistic                -9.975959e+00
# p-value                        2.177367e-17
# #Lags Used                     3.500000e+01
# Number of Observations Used    8.181000e+03
# Critical Value (1%)           -3.431150e+00
# Critical Value (5%)           -2.861893e+00
# Critical Value (10%)          -2.566958e+00
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_S_Agata':
# Test Statistic                -1.054162e+01
# p-value                        8.620360e-19
# #Lags Used                     3.400000e+01
# Number of Observations Used    8.182000e+03
# Critical Value (1%)           -3.431149e+00
# Critical Value (5%)           -2.861893e+00
# Critical Value (10%)          -2.566958e+00
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_Mangona':
# Test Statistic                -9.507026e+00
# p-value                        3.326103e-16
# #Lags Used                     3.500000e+01
# Number of Observations Used    8.181000e+03
# Critical Value (1%)           -3.431150e+00
# Critical Value (5%)           -2.861893e+00
# Critical Value (10%)          -2.566958e+00
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_S_Piero':
# Test Statistic                -1.017128e+01
# p-value                        7.078952e-18
# #Lags Used                     3.400000e+01
# Number of Observations Used    8.182000e+03
# Critical Value (1%)           -3.431149e+00
# Critical Value (5%)           -2.861893e+00
# Critical Value (10%)          -2.566958e+00
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_Vernio':
# Test Statistic                -8.121816e+00
# p-value                        1.150656e-12
# #Lags Used                     3.500000e+01
# Number of Observations Used    8.181000e+03
# Critical Value (1%)           -3.431150e+00
# Critical Value (5%)           -2.861893e+00
# Critical Value (10%)          -2.566958e+00
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Rainfall_Incisa':
# Test Statistic                -8.850293e+00
# p-value                        1.579649e-14
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.179000e+03
# Critical Value (1%)           -3.431150e+00
# Critical Value (5%)           -2.861893e+00
# Critical Value (10%)          -2.566958e+00
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Temperature_Firenze':
# Test Statistic                   -4.440175
# p-value                           0.000252
# #Lags Used                       14.000000
# Number of Observations Used    8202.000000
# Critical Value (1%)              -3.431148
# Critical Value (5%)              -2.861892
# Critical Value (10%)             -2.566958
# dtype: float64
# --------------------------------------------------------------------------------
# Resultados de la prueba de Dickey-Fuller para 'Hydrometry_Nave_di_Rosano':
# Test Statistic                -7.825536e+00
# p-value                        6.496928e-12
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.179000e+03
# Critical Value (1%)           -3.431150e+00
# Critical Value (5%)           -2.861893e+00
# Critical Value (10%)          -2.566958e+00
# dtype: float64
# --------------------------------------------------------------------------------

# %% [markdown]
# # Análisis de variabilidad

# %%
utils.plot_variability(df, period=365)

# %% [markdown]
# # Análisis de autocorrelación

# %%
utils.plot_autocorrelation(df)

# %%
df.to_csv("../../data/processed/river_arno.csv", index=True)
